# %%
import os, sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import json
import pydicom
import skimage.io
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob 
from skimage.transform import resize

import keras
# Out:
# Using TensorFlow backend.

# %%
DATA_DIR = '../pneumonia/'
ROOT_DIR = './'

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_2_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_2_test_images')

def parse_dataset(anns): 
    image_annotations = []
    for index, row in anns.iterrows():
        row['path'] = os.path.join(train_dicom_dir, row['patientId']+'.dcm')
        image_annotations.append(row)
    return image_annotations 

# training dataset
labels = pd.read_csv(os.path.join(DATA_DIR, 'stage_2_train_labels.csv'))
labels = labels.drop_duplicates(["patientId"])

positive_dataset = labels[labels["Target"] == 1]
negative_dataset = labels[labels["Target"] == 0]

positive_image_ids = parse_dataset(anns=positive_dataset)
negative_image_ids = parse_dataset(anns=negative_dataset)


train_positive_size = round(len(positive_image_ids) * 0.7)
validation_positive_size = round(len(negative_image_ids) * 0.15)

train_positive_ids = positive_image_ids[:train_positive_size]
validation_positive_ids = positive_image_ids[train_positive_size:(train_positive_size+validation_positive_size)]
test_positive_ids = positive_image_ids[(train_positive_size+validation_positive_size):]


train_negative_size = round(len(negative_image_ids) * 0.7)
validation_negative_size = round(len(negative_image_ids) * 0.15)

train_negative_ids = negative_image_ids[:train_negative_size]
validation_negative_ids = negative_image_ids[train_negative_size:(train_negative_size+validation_negative_size)]
test_negative_ids = negative_image_ids[(train_negative_size+validation_negative_size):]

print(len(positive_image_ids))
print(len(negative_image_ids))

train_image_annotations = train_positive_ids + train_negative_ids
validation_image_annotations = validation_positive_ids + validation_negative_ids
test_image_annotations = test_positive_ids + test_negative_ids

print("Train annotations:", len(train_image_annotations))
print("Validation annotations:", len(validation_image_annotations))
print("Test annotations:", len(test_image_annotations))
# Out:
# 6012
# 20672
# Train annotations: 18678
# Validation annotations: 4905
# Test annotations: 3101

# %%
import random

random.shuffle(train_image_annotations)
random.shuffle(validation_image_annotations)
random.shuffle(test_image_annotations)

# %%
class train_data_generator:
    
    def create(dataset_info, batch_size, shape, border=128):
        while True:
                        
            batch_info = [dataset_info[i] for i in np.random.choice(len(dataset_info), batch_size)]
            batch_crop_image = np.empty((batch_size, shape[0], shape[1], shape[2]))
            batch_labels = np.zeros((batch_size,1))
            for i, e in enumerate(batch_info):
                
                #get fullsize image
                fp = e['path']
                full_image = None
                if fp.split('.')[-1] == 'dcm':
                    ds = pydicom.read_file(fp)
                    full_image = ds.pixel_array
                if fp.split('.')[-1] == 'jpeg' or fp.split('.')[-1] == 'png':
                    full_image = skimage.io.imread(fp)
                
                # crop image
                if not e['Target']:
                    x = np.random.randint(border, full_image.shape[0]-shape[0]-border)
                    y = np.random.randint(border, full_image.shape[1]-shape[1]-border)
                else:
                    x = int(e['x'] + (e['width']/2) - (shape[0]/2))
                    y = int(e['y'] + (e['height']/2) - (shape[1]/2))
                    batch_labels[i] = 1
                    
                crop_image = full_image[y:y+shape[0], x:x+shape[1]].copy()
                
                if np.random.uniform(0,1) > 0.5:
                    crop_image = np.fliplr(crop_image)
                
                if crop_image.shape[:2] != (shape[0], shape[1]):
                    break
                
                # If grayscale. Convert to RGB for consistency.
                if len(crop_image.shape) == 3:
                    if crop_image.shape[2] > 3:
                        crop_image = crop_image[:,:,0]
                if len(crop_image.shape) != 3 or crop_image.shape[2] != 3:
                    crop_image = np.stack((crop_image,) * 3, -1)
                batch_crop_image[i] = crop_image
            yield batch_crop_image/255, batch_labels

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.callbacks import ModelCheckpoint
from keras import metrics
from keras.optimizers import Adam 
from keras import backend as K
import keras

def create_model(input_shape, n_out):
    pretrain_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=input_shape)
    model = Sequential()
    model.add(pretrain_model)
    model.add(Flatten())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(n_out))
    model.add(Activation('sigmoid'))
    return model

# %%
keras.backend.clear_session()

if os.path.exists('./keras.model'):
    model = load_model('./keras.model')
elif os.path.exists('./inceptionresnetv2-classificator/keras.model'):
    model = load_model('./inceptionresnetv2-classificator/keras.model')
else:
    model = create_model(
        input_shape=(299,299,3),
        n_out=1)

model.layers[0].trainable = False

model.compile(
    loss='binary_crossentropy', 
    optimizer=Adam(0.000001), 
    metrics=['acc'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 8, 8, 1536)        54336736
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 98304)             0
# _________________________________________________________________
# activation_204 (Activation)  (None, 98304)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 98304)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              100664320
# _________________________________________________________________
# activation_205 (Activation)  (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# _________________________________________________________________
# activation_206 (Activation)  (None, 1)                 0
# =================================================================
# Total params: 155,002,081
# Trainable params: 100,665,345
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
epochs = 50; batch_size = 16
checkpointer = ModelCheckpoint(
    './keras.model', 
    verbose=2, 
    save_best_only=True)

train_generator = train_data_generator.create(
    train_image_annotations, batch_size, (299,299,3))
validation_generator = train_data_generator.create(
    validation_image_annotations, 100, (299,299,3))

history = model.fit_generator(
    train_generator,
    steps_per_epoch=100,
    validation_data=next(validation_generator),
    epochs=epochs, 
    verbose=1,
    callbacks=[checkpointer])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 47s 470ms/step - loss: 0.6673 - acc: 0.7206 - val_loss: 0.9046 - val_acc: 0.6300
#
# Epoch 00001: val_loss improved from inf to 0.90457, saving model to ./keras.model
# Epoch 2/50
# 100/100 [==============================] - 28s 279ms/step - loss: 0.5955 - acc: 0.7325 - val_loss: 0.8442 - val_acc: 0.6300
#
# Epoch 00002: val_loss improved from 0.90457 to 0.84425, saving model to ./keras.model
# Epoch 3/50
# 100/100 [==============================] - 28s 279ms/step - loss: 0.5250 - acc: 0.7669 - val_loss: 0.8190 - val_acc: 0.6300
#
# Epoch 00003: val_loss improved from 0.84425 to 0.81898, saving model to ./keras.model
# Epoch 4/50
# 100/100 [==============================] - 28s 279ms/step - loss: 0.5178 - acc: 0.7644 - val_loss: 0.7648 - val_acc: 0.6500
#
# Epoch 00004: val_loss improved from 0.81898 to 0.76483, saving model to ./keras.model
# Epoch 5/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.5038 - acc: 0.7794 - val_loss: 0.7280 - val_acc: 0.6600
#
# Epoch 00005: val_loss improved from 0.76483 to 0.72803, saving model to ./keras.model
# Epoch 6/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4784 - acc: 0.7788 - val_loss: 0.7618 - val_acc: 0.6500
#
# Epoch 00006: val_loss did not improve from 0.72803
# Epoch 7/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4688 - acc: 0.7881 - val_loss: 0.8290 - val_acc: 0.6300
#
# Epoch 00007: val_loss did not improve from 0.72803
# Epoch 8/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4704 - acc: 0.7769 - val_loss: 0.8030 - val_acc: 0.6400
#
# Epoch 00008: val_loss did not improve from 0.72803
# Epoch 9/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4517 - acc: 0.8012 - val_loss: 0.6999 - val_acc: 0.6700
#
# Epoch 00009: val_loss improved from 0.72803 to 0.69993, saving model to ./keras.model
# Epoch 10/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4755 - acc: 0.7806 - val_loss: 0.7729 - val_acc: 0.6600
#
# Epoch 00010: val_loss did not improve from 0.69993
# Epoch 11/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4231 - acc: 0.8031 - val_loss: 0.8353 - val_acc: 0.6400
#
# Epoch 00011: val_loss did not improve from 0.69993
# Epoch 12/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4484 - acc: 0.8056 - val_loss: 0.7786 - val_acc: 0.6500
#
# Epoch 00012: val_loss did not improve from 0.69993
# Epoch 13/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4207 - acc: 0.8138 - val_loss: 0.7649 - val_acc: 0.6600
#
# Epoch 00013: val_loss did not improve from 0.69993
# Epoch 14/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4085 - acc: 0.8181 - val_loss: 0.8290 - val_acc: 0.6400
#
# Epoch 00014: val_loss did not improve from 0.69993
# Epoch 15/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3872 - acc: 0.8275 - val_loss: 0.9437 - val_acc: 0.6300
#
# Epoch 00015: val_loss did not improve from 0.69993
# Epoch 16/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4291 - acc: 0.8100 - val_loss: 0.8003 - val_acc: 0.6400
#
# Epoch 00016: val_loss did not improve from 0.69993
# Epoch 17/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3865 - acc: 0.8281 - val_loss: 0.8766 - val_acc: 0.6300
#
# Epoch 00017: val_loss did not improve from 0.69993
# Epoch 18/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.4092 - acc: 0.8188 - val_loss: 0.8946 - val_acc: 0.6300
#
# Epoch 00018: val_loss did not improve from 0.69993
# Epoch 19/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3668 - acc: 0.8406 - val_loss: 0.8010 - val_acc: 0.6400
#
# Epoch 00019: val_loss did not improve from 0.69993
# Epoch 20/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3884 - acc: 0.8275 - val_loss: 0.8836 - val_acc: 0.6400
#
# Epoch 00020: val_loss did not improve from 0.69993
# Epoch 21/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3796 - acc: 0.8281 - val_loss: 0.9922 - val_acc: 0.6300
#
# Epoch 00021: val_loss did not improve from 0.69993
# Epoch 22/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3713 - acc: 0.8313 - val_loss: 0.9097 - val_acc: 0.6300
#
# Epoch 00022: val_loss did not improve from 0.69993
# Epoch 23/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3773 - acc: 0.8288 - val_loss: 0.8023 - val_acc: 0.6500
#
# Epoch 00023: val_loss did not improve from 0.69993
# Epoch 24/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3788 - acc: 0.8225 - val_loss: 0.7984 - val_acc: 0.6600
#
# Epoch 00024: val_loss did not improve from 0.69993
# Epoch 25/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3521 - acc: 0.8512 - val_loss: 0.9394 - val_acc: 0.6300
#
# Epoch 00025: val_loss did not improve from 0.69993
# Epoch 26/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3530 - acc: 0.8425 - val_loss: 0.9221 - val_acc: 0.6300
#
# Epoch 00026: val_loss did not improve from 0.69993
# Epoch 27/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3651 - acc: 0.8413 - val_loss: 0.8521 - val_acc: 0.6400
#
# Epoch 00027: val_loss did not improve from 0.69993
# Epoch 28/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.3438 - acc: 0.8587 - val_loss: 0.9240 - val_acc: 0.6300
#
# Epoch 00028: val_loss did not improve from 0.69993
# Epoch 29/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3366 - acc: 0.8519 - val_loss: 0.9805 - val_acc: 0.6300
#
# Epoch 00029: val_loss did not improve from 0.69993
# Epoch 30/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3591 - acc: 0.8431 - val_loss: 0.8969 - val_acc: 0.6300
#
# Epoch 00030: val_loss did not improve from 0.69993
# Epoch 31/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3264 - acc: 0.8631 - val_loss: 0.9490 - val_acc: 0.6300
#
# Epoch 00031: val_loss did not improve from 0.69993
# Epoch 32/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3730 - acc: 0.8288 - val_loss: 0.9239 - val_acc: 0.6300
#
# Epoch 00032: val_loss did not improve from 0.69993
# Epoch 33/50
# 100/100 [==============================] - 28s 282ms/step - loss: 0.3618 - acc: 0.8450 - val_loss: 0.9451 - val_acc: 0.6300
#
# Epoch 00033: val_loss did not improve from 0.69993
# Epoch 34/50
# 100/100 [==============================] - 28s 282ms/step - loss: 0.3544 - acc: 0.8481 - val_loss: 0.9054 - val_acc: 0.6300
#
# Epoch 00034: val_loss did not improve from 0.69993
# Epoch 35/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3280 - acc: 0.8556 - val_loss: 0.8095 - val_acc: 0.6500
#
# Epoch 00035: val_loss did not improve from 0.69993
# Epoch 36/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3326 - acc: 0.8512 - val_loss: 0.9204 - val_acc: 0.6300
#
# Epoch 00036: val_loss did not improve from 0.69993
# Epoch 37/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3448 - acc: 0.8575 - val_loss: 0.9745 - val_acc: 0.6300
#
# Epoch 00037: val_loss did not improve from 0.69993
# Epoch 38/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3062 - acc: 0.8650 - val_loss: 0.9042 - val_acc: 0.6300
#
# Epoch 00038: val_loss did not improve from 0.69993
# Epoch 39/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3663 - acc: 0.8319 - val_loss: 0.9088 - val_acc: 0.6300
#
# Epoch 00039: val_loss did not improve from 0.69993
# Epoch 40/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3305 - acc: 0.8619 - val_loss: 1.0329 - val_acc: 0.6300
#
# Epoch 00040: val_loss did not improve from 0.69993
# Epoch 41/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3555 - acc: 0.8356 - val_loss: 0.9073 - val_acc: 0.6300
#
# Epoch 00041: val_loss did not improve from 0.69993
# Epoch 42/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3199 - acc: 0.8606 - val_loss: 0.9455 - val_acc: 0.6300
#
# Epoch 00042: val_loss did not improve from 0.69993
# Epoch 43/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3397 - acc: 0.8519 - val_loss: 0.9103 - val_acc: 0.6300
# Epoch 00043: val_loss did not improve from 0.69993
# Epoch 44/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3100 - acc: 0.8625 - val_loss: 0.9918 - val_acc: 0.6300
#
# Epoch 00044: val_loss did not improve from 0.69993
# Epoch 45/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3404 - acc: 0.8531 - val_loss: 0.8894 - val_acc: 0.6400
#
# Epoch 00045: val_loss did not improve from 0.69993
# Epoch 46/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.2912 - acc: 0.8756 - val_loss: 1.0208 - val_acc: 0.6300
#
# Epoch 00046: val_loss did not improve from 0.69993
# Epoch 47/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3444 - acc: 0.8475 - val_loss: 1.0626 - val_acc: 0.6300
#
# Epoch 00047: val_loss did not improve from 0.69993
# Epoch 48/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3417 - acc: 0.8575 - val_loss: 0.8867 - val_acc: 0.6500
#
# Epoch 00048: val_loss did not improve from 0.69993
# Epoch 49/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3512 - acc: 0.8456 - val_loss: 0.9917 - val_acc: 0.6300
#
# Epoch 00049: val_loss did not improve from 0.69993
# Epoch 50/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.3375 - acc: 0.8587 - val_loss: 0.9269 - val_acc: 0.6400
#
# Epoch 00050: val_loss did not improve from 0.69993

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].set_title('loss')
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[1].set_title('acc')
ax[1].plot(history.epoch, history.history["acc"], label="Train acc")
ax[1].plot(history.epoch, history.history["val_acc"], label="Validation acc")
ax[0].legend()
ax[1].legend()

# %%
if os.path.exists('./keras.model'):
    model = load_model('./keras.model')
elif os.path.exists('./inceptionresnetv2-classificator/keras.model'):
    model = load_model('./inceptionresnetv2-classificator/keras.model')
    # !cp "./inceptionresnetv2-classificator/keras.model" "./"
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\ops.py in get_attr(self, name)
#    2382       with c_api_util.tf_buffer() as buf:
# -> 2383         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2384         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'inception_resnet_v2_2/batch_normalization_194/cond' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     344     try:
# --> 345       xla_compile = op.get_attr("_XlaCompile")
#     346       xla_separate_compiled_gradients = op.get_attr(
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\ops.py in get_attr(self, name)
#    2386       # Convert to ValueError for backwards compatibility.
# -> 2387       raise ValueError(str(e))
#    2388     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'inception_resnet_v2_2/batch_normalization_194/cond' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-49f85ffa9c4b> in <module>
#       1 if os.path.exists('./keras.model'):
# ----> 2     model = load_model('./keras.model')
#       3 elif os.path.exists('./inceptionresnetv2-classificator/keras.model'):
#       4     model = load_model('./inceptionresnetv2-classificator/keras.model')
#       5     get_ipython().system('cp "./inceptionresnetv2-classificator/keras.model" "./"')
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     372         if 'optimizer_weights' in h5dict:
#     373             # Build train function (to get weight updates).
# --> 374             model._make_train_function()
#     375             optimizer_weights_group = h5dict['optimizer_weights']
#     376             optimizer_weight_names = [
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training.py in _make_train_function(self)
#     314                     training_updates = self.optimizer.get_updates(
#     315                         params=self._collected_trainable_weights,
# --> 316                         loss=self.total_loss)
#     317                 updates = self.updates + training_updates
#     318
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\optimizers.py in get_updates(self, loss, params)
#     502     @K.symbolic
#     503     def get_updates(self, loss, params):
# --> 504         grads = self.get_gradients(loss, params)
#     505         self.updates = [K.update_add(self.iterations, 1)]
#     506
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\optimizers.py in get_gradients(self, loss, params)
#      89
#      90     def get_gradients(self, loss, params):
# ---> 91         grads = K.gradients(loss, params)
#      92         if any(x is None for x in grads):
#      93             raise ValueError('An operation has `None` for gradient. '
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in gradients(loss, variables)
#    3023     if _is_tf_1():
#    3024         return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
# -> 3025     return tf.gradients(loss, variables)
#    3026
#    3027
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\gradients_impl.py in gradients_v2(ys, xs, grad_ys, name, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients)
#     272         ys, xs, grad_ys, name, True, gate_gradients,
#     273         aggregation_method, stop_gradients,
# --> 274         unconnected_gradients)
#     275   # pylint: enable=protected-access
#     276
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     677                 # functions.
#     678                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 679                                          lambda: grad_fn(op, *out_grads))
#     680               else:
#     681                 # For function call ops, we add a 'SymbolicGradient'
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     348       xla_scope = op.get_attr("_XlaScope").decode()
#     349     except ValueError:
# --> 350       return grad_fn()  # Exit early
#     351
#     352   if not xla_compile:
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in <lambda>()
#     677                 # functions.
#     678                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 679                                          lambda: grad_fn(op, *out_grads))
#     680               else:
#     681                 # For function call ops, we add a 'SymbolicGradient'
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\cond_v2.py in _IfGrad(op, *grads)
#     108   # Get the if operator (this logic handles the case where op is a MockOp)
#     109   if_op = op.outputs[0].op
# --> 110   true_graph, false_graph = get_func_graphs(if_op)
#     111   # Note: op.graph != ops.get_default_graph() when we are computing the gradient
#     112   # of a nested cond.
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\cond_v2.py in get_func_graphs(op)
#     329
#     330   if op.type in ["If", "StatelessIf"]:
# --> 331     return (_get_func_graph_for_branch(op.get_attr("then_branch")),
#     332             _get_func_graph_for_branch(op.get_attr("else_branch")))
#     333   elif op.type == "Case":
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\cond_v2.py in _get_func_graph_for_branch(name_attr_list)
#     320     with op.graph.as_default():
#     321       func_graph = function_def_to_graph.function_def_to_graph(
# --> 322           fdef, input_shapes)
#     323     for external_t, internal_t in zip(inputs, func_graph.inputs):
#     324       custom_gradient.copy_handle_data(external_t, internal_t)
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\function_def_to_graph.py in function_def_to_graph(fdef, input_shapes, copy_functions)
#      63   with func_graph.as_default():
#      64     # Add all function nodes to the graph.
# ---> 65     importer.import_graph_def_for_function(graph_def, name="")
#      66
#      67     # Initialize fields specific to FuncGraph.
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\importer.py in import_graph_def_for_function(graph_def, name)
#     410   """Like import_graph_def but does not validate colocation constraints."""
#     411   return _import_graph_def_internal(
# --> 412       graph_def, validate_colocation_constraints=False, name=name)
#     413
#     414
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\importer.py in _import_graph_def_internal(graph_def, input_map, return_elements, validate_colocation_constraints, name, op_dict, producer_op_list)
#     518
#     519   if graph_def.library and graph_def.library.function:
# --> 520     functions = function.from_library(graph_def.library)
#     521     for f in functions:
#     522       f.add_to_graph(graph)
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\function.py in from_library(lib)
#    1165     if func_to_grad[name]:
#    1166       assert grad
# -> 1167     defined_func = _from_definition(fdef, grad_func=grad)
#    1168     initialized[name] = defined_func
#    1169
#
# C:\Development\Anaconda\envs\tensorflow\lib\site-packages\tensorflow_core\python\framework\function.py in _from_definition(fdef, grad_func)
#    1100   # pylint: disable=protected-access
#    1101   serialized = fdef.SerializeToString()
# -> 1102   c_func = c_api.TF_FunctionImportFunctionDef(serialized)
#    1103   result._c_func = c_api_util.ScopedTFFunction(c_func)
#    1104   result._extra_inputs = []
#
# KeyboardInterrupt:

# %%
validation_generator = train_data_generator.create(
    validation_image_annotations, 100, (299,299,3))

# %%
true_labels = []; predict_labels = []; 
for i in range(50):
    imgs, labels = next(validation_generator)
    true_labels += [int(label) for label in labels]
    predict_labels += [float(predict) for predict in model.predict(imgs)]

# %%
true_labels = np.array(true_labels)
predict_labels = (np.array(predict_labels) > 0.5).astype(int)

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(
    confusion_matrix(true_labels, predict_labels),
    columns=[['predict', 'predict'],['N', 'P']],
    index=[['true', 'true'],['N', 'P']])

# %%
from sklearn.metrics import f1_score
f1_score(true_labels, predict_labels, average='macro')
